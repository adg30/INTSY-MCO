# %% [markdown]
# ## Section 4: Model Selection and Training
#
# In this section, we will:
# - Select and train **Classical Model 1**
# - Select and train **Classical Model 2**
# - Select and train **Neural Network Model**
# - Provide justification for model choices
# - Train models and monitor performance on validation set
# - One of the models must be the xgboost gradient boost model to compare with [other notebook](https://www.kaggle.com/code/camerondorsey/dnd-5e-monster-cr-regression-model)

# %% [markdown]
# ### Classical Model 1:
# Justification:

# %%
# Placeholder for Classical Model 1 training
# e.g. Linear Regression, Random Forest, or Gradient Boosting
# - instantiate model
# - fit on training data
# - evaluate on validation set

# %% [markdown]
# ### Classical Model 2:
# Justification:

# %%
# Placeholder for Classical Model 2 training
# choose a different algorithm from Model 1 to compare performance
# remember to record hyperparameters and validation metrics

# %% [markdown]
# ### Neural Network Model:
# Justification:

# %%
# Placeholder for Neural Network model construction and training
# - define architecture (e.g. number of layers, neurons, activation functions), maybe using keras or pytorch
# - compile with appropriate loss and optimizer
# - fit on scaled training data and monitor validation loss
# TODO: add another point after doing NN notebook
